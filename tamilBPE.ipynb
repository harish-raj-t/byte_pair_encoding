txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_54.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_71.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_07.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_08.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_07.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_29.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_97.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_03.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_06.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_98.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_48.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_84.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_36.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_19.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_72.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_21.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_89.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_22.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_28.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_65.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_93.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_21.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_00.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_37.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_06.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_35.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_27.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_74.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_84.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_81.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_96.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_38.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_06.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_46.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_00.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_09.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_86.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_91.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_98.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_28.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_82.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_71.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_39.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_11.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_39.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_13.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_81.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_47.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_20.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_56.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_95.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_81.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_48.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_16.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_01.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_41.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_67.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_66.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_25.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_10.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_94.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_23.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_14.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_48.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_17.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_00.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_22.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_66.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_64.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_49.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_81.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_50.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_37.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_28.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_93.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_98.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_90.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_31.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_34.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_33.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_53.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_41.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_03.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_72.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_11.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_52.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AE_wiki_42.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_88.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_05.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_88.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_98.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AC_wiki_74.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_60.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_12.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_10.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AB_wiki_93.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AD_wiki_38.txt
# /kaggle/input/tamil-wikipedia-articles/train/train/AA_wiki_95.txt

# %%
# !pip install open-tamil
# Out:
# Requirement already satisfied: open-tamil in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import tamil
import pickle

seed = 1234
torch.manual_seed(seed)

# %%
class BytePairEncoder:
    def __init__(self, vocab_size=1000):
        
        self.vocab_size = vocab_size
        self.vocab = {}  
        self.inverse_vocab = {} 
        self.merges = []  

    def extract_sentences(self, text):
        return [line.strip()+' <EOS>' for line in text.split(".") if len(line.split(" ")) > 2]

    def train(self, content):
        texts = self.extract_sentences(content)
        #word_counts = {low:1, lower:2, high:1}
        word_counts = {}
        for text in texts:
            idx = 0
            for word in text.split():
                if idx!=0:
                    word = "Ġ"+word
                else:
                    idx += 1
                if word not in word_counts:
                    word_counts[word] = 0
                word_counts[word] += 1
        #word_vocab = {l o w:1, l o w e r:2, h i g h:1}
        word_vocab = {}

        for word, count in word_counts.items():
            parts = word.split('Ġ')
            core_word = parts[-1]  
            if core_word == '<EOS>':
                word_vocab['Ġ' + ' <EOS>'] = count
            elif re.match(r'^[\d,.-]+$', core_word):  
                word_vocab['Ġ ' + core_word] = count  
        
            elif re.search(r'[க-ஹ]+[a-zA-Z]+|[a-zA-Z]+[க-ஹ]+', core_word):  
                word_vocab['Ġ ' + core_word] = count  
        
            elif re.match(r'^[\W_]+$', core_word):  
                word_vocab['Ġ ' + core_word] = count  
        
            else:
                chars = tamil.utf8.get_letters(word) 
                word_vocab[" ".join(chars)] = count 
                
        #initial_vocab = {l, o ,w, e, r, h, i, g}
        initial_vocab = set()
        for word in word_vocab.keys():
            initial_vocab.update(word.split())

        #'b': 0, # 'd': 1}, self.vocab[char]
        #{0: 'b',1: 'd'} self.inverse_vocab[i]
        for i, char in enumerate(sorted(initial_vocab)):
            self.vocab[char] = i
            self.inverse_vocab[i] = char
        
        #next_id = 12 for example
        next_id = len(self.vocab)
        print(next_id)
        while len(self.vocab) < self.vocab_size:
            pairs = self._get_pairs(word_vocab)
            if not pairs:
                break
            best_pair = max(pairs, key=pairs.get)
            new_token = best_pair[0] + best_pair[1]
            self.merges.append(best_pair)
            
            self.vocab[new_token] = next_id
            self.inverse_vocab[next_id] = new_token
            next_id += 1
            
            new_vocab = {}
            bigram = ' '.join(best_pair)
            replacement = ''.join(best_pair)
            
            for word, count in word_vocab.items():
                new_word = word.replace(bigram, replacement)
                new_vocab[new_word] = count
                
            word_vocab = new_vocab
            
            if len(self.vocab) >= self.vocab_size:
                break
    
    def _get_pairs(self, word_vocab):
        pairs = {}
        for word, count in word_vocab.items():
            symbols = word.split()
            for i in range(len(symbols) - 1):
                pair = (symbols[i], symbols[i + 1])
                pairs[pair] = pairs.get(pair, 0) + count
        return pairs
    
    def encode(self, text):
        tokens = []
        for word in text.split():
            word = " ".join(list(word))
            
            for pair in self.merges:
                bigram = ' '.join(pair)
                replacement = ''.join(pair)
                word = word.replace(bigram, replacement)
            
            for subword in word.split():
                if subword in self.vocab:
                    tokens.append(self.vocab[subword])
                else:
                    for char in subword:
                        if char in self.vocab:
                            tokens.append(self.vocab[char])
        
        return tokens
    
    def decode(self, ids):
        tokens = [self.inverse_vocab[id] if id in self.inverse_vocab else '<UNK>' for id in ids]
        return ''.join(tokens)

# %%
def save_model_pickle(bpe, filename="bpe_model.pkl"):
    with open(filename, "wb") as f:
        pickle.dump(bpe, f)

def load_model_pickle(filename="bpe_model.pkl"):
    with open(filename, "rb") as f:
        return pickle.load(f)

# %%
import os

def load_text_from_folder(folder_path):
    all_text = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    all_text.append(content)
            except Exception as e:
                print(f"Skipping {file_path}: {e}")
    return " ".join(all_text)

folder_path = "/kaggle/input/tamil-wikipedia-articles/valid/valid"
full_corpus = load_text_from_folder(folder_path)
print(len(full_corpus))
#full_corpus = full_corpus[:10000]
bpe = BytePairEncoder(vocab_size=50000)
bpe.train(full_corpus)
#print(bpe.merges)
save_model_pickle(bpe, "bpe_model.pkl")
# Out:
# 73619256
# 211
# [('Ġ', '<EOS>'), ('Ġ', 'இ'), ('Ġ', 'அ'), ('ம்', ','), ('Ġ', 'க'), ('ட்', 'ட'), ('Ġ', 'எ'), ('Ġ', 'வ'), ('Ġ', 'ப'), ('த்', 'தி'), ('ந்', 'து'), ('Ġ', 'ம'), ('க்', 'கு'), ('Ġ', 'ஆ'), ('தி', 'ரு'), ('ப்', 'ப'), ('க', 'ள்'), ('நெ', 'ல்'), ('Ġ', 'உ'), ('ந்', 'த'), ('Ġ', 'திரு'), ('வ', 'ட்ட'), ('Ġஎ', 'ன்'), ('க்', 'க'), ('ற்', 'கு'), ('ய', 'ர்'), ('Ġ', 'த'), ('த்', 'து'), ('யி', 'ல்'), ('வே', 'லி'), ('ன்', 'ற'), ('நெல்', 'வேலி'), ('கு', 'ம்'), ('Ġ', 'ந'), ('ங்', 'க'), ('ள்', 'ள'), ('ற்', 'று'), ('Ġ', 'செ'), ('Ġஅ', 'ரு'), ('த்தி', 'ல்'), ('Ġமா', 'வட்ட'), ('ற', 'து'), ('த்', 'த'), ('ல்', 'லு'), ('ரு', 'ம்'), ('Ġதிரு', 'நெல்வேலி'), ('வி', 'ல்'), (':', '-'), ('Ġ', 'சி'), ('வ', 'ர்'), ('Ġஇ', 'ம்'), ('மா', 'வட்ட'), ('ல்லு', 'ரி'), ('Ġஅரு', 'வி'), ('க', 'ளி'), ('Ġகோ', 'வில்'), ('Ġஅ', 'மை'), ('Ġந', 'தி'), ('Ġ', 'சு'), ('Ġஇம்', 'மாவட்ட'), ('Ġபோ', 'ன்ற'), ('Ġக', 'ல்லுரி'), ('ள', 'ம்'), ('ற்', 'ற'), ('Ġ', 'ச'), ('Ġஇ', 'ட'), ('ப', 'ர'), ('யு', 'ம்'), ('Ġவ', 'ர'), ('ப்ப', 'டு'), ('கி', 'றது'), ('Ġஎன்', 'னு'), ('Ġஎன்னு', 'ம்'), ('த்தி', 'ற்கு'), ('யி', 'ன்'), ('Ġபெ', 'ரு'), ('Ġக', 'ட'), ('Ġகோவில்', ','), ('ள', 'வீ'), ('Ġமாவட்ட', 'ம்'), ('Ġஉ', 'ரு'), ('ந', 'க'), ('Ġவர', 'லா'), ('ண்', 'ட'), ('Ġ', '“'), ('று', 'ம்'), ('Ġஅமை', 'ந்து'), ('Ġஅமைந்து', 'ள்ள'), ('மி', 'ர'), ('னா', 'ர்'), ('Ġம', 'லை'), ('லி', 'ல்'), ('Ġ', 'ஊ'), ('ரி', 'ய'), ('ச்', 'சி'), ('Ġஉ', 'ள்ள'), ('ய', 'ம்'), ('=', '"'), ('Ġஉரு', 'வா'), ('க்க', 'ப்ப'), ('Ġவீ', 'ர'), ('Ġமொ', 'ழி'), ('க்கி', 'ய'), ('Ġபெ', 'யர்'), ('ல்', 'லா'), ('Ġ', 'ஒ'), ('மிர', 'பர'), ('மிரபர', 'ணி'), ('ட', 'ன்'), ('Ġக', 'ல'), ('Ġமு', 'த'), ('Ġப', 'ல'), ('Ġசே', 'ர்'), ('Ġஅருவி', ','), ('Ġஇம்மாவட்ட', 'ம்'), ('Ġமு', 'றை'), ('ச்', 'சு'), ('Ġஆ', 'ங்கி'), ('Ġஆ', 'கும்'), ('களி', 'ன்'), ('ரு', 'ந்த'), ('Ġவ', 'கை'), ('ல்லா', 'ம்'), ('Ġநெல்', 'லை'), ('ம', 'ணி'), ('Ġஎ', 'ன'), ('Ġபி', 'ற'), ('Ġஆ', 'கி'), ('லு', 'ம்'), ('ம', 'லை'), ('மொ', 'ழி'), ('வு', 'ம்'), ('யா', 'க'), ('க', 'ல்'), ('Ġதெ', 'ன்'), ('Ġஇம்மாவட்டம்', ':-'), ('Ġம', 'ற்றும்'), ('Ġமாவட்ட', 'த்தில்'), ('Ġத', 'மி'), ('Ġபெரு', 'மை'), ('கு', 'தி'), ('Ġ', '('), ('ய்', ','), ('Ġஅ', 'ளவீ'), ('i', 'd'), ('3', '2'), ('32', '0'), ('320', '3'), ('u', 'r'), ('க்கப்ப', 'ட்ட'), ('திரு', 'நெல்வேலி'), ('Ġவ', 'ள'), ('Ġபெ', 'ற்ற'), ('Ġநி', 'ல'), ('ழ்', 'ந்து'), ('Ġஇ', 'து'), ('Ġவரலா', 'று'), ('Ġஇ', 'ந்'), ('Ġதா', 'மிரபரணி'), ('ட்டு', 'ம்'), ('இ', 'வ்'), ('நக', 'ரி'), ('ரு', 'நை'), ('யா', 'று'), ('ற்றா', 'ல'), ('Ġ', 'ஐ'), ('ரு', 'வி'), ('வா', 'ர்'), ('ர', 'ம்,'), ('Ġஆகி', 'ய'), ('Ġசு', 'ந்த'), ('Ġசுந்த', 'ர'), ('ஞ்', 'சி'), ('தா', 'ன்'), ('Ġசெ', 'ய்'), ('ய', 'ல்'), ('Ġச', 'ர'), ('Ġசர', 'ணா'), ('Ġசரணா', 'ல'), ('க', 'லை'), ('Ġகல்லுரி', ','), ('Ġப', 'யி'), ('ர்', 'ட்டு'), ('Ġகா', 'ற்று'), ('Ġகாற்று', 'வீ'), ('Ġஅளவீ', 'டு'), ('d', 'o'), ('do', 'c'), ('o', 'r'), ('l', 'e'), ('டா', 'ர'), ('டார', 'க்கு'), ('டாரக்கு', 'ளம்'), ('Ġசீ', 'ர்'), ('ட', 'ம்'), ('Ġ', '1'), ('Ġஆங்கி', 'லே'), ('Ġஉருவா', 'க்கப்பட்ட'), ('Ġஉருவாக்கப்பட்ட', 'து'), ('ரா', 'க'), ('ல', 'க்கிய'), ('Ġசி', 'ற'), ('Ġபு', 'க'), ('Ġபா', 'டி'), ('Ġபு', 'ண்'), ('Ġநெல்லை', 'ய'), ('ர', 'ம்'), ('Ġஇ', 'றை'), ('Ġஇறை', 'வ'), ('க', 'ளை'), ('ங்க', 'ர'), ('Ġஇட', 'த்திற்கு'), ('Ġஅ', 'டி'), ('Ġநதி', 'யின்'), ('Ġகா', 'ண'), ('Ġபிற', 'ந்து'), ('தி', 'ய'), ('Ġவ', 'ட'), ('ண', 'ர்'), ('செ', 'ய்'), ('லி', 'ருந்து'), ('ம்', 'பா'), ('றி', 'ச்சி'), ('ம', 'ரு'), ('கி', 'ன்ற'), ('கின்ற', 'ன'), ('Ġகல', 'க்கிறது'), ('Ġகு', 'ற்றால'), ('கி', 'ல்'), ('ழ்', 'வார்'), ('Ġஊ', 'ர்'), ('Ġஅ', 'னை'), ('Ġஉள்ள', 'து'), ('ப', 'நா'), ('பநா', 'ச'), ('பநாச', 'ம்,'), ('Ġஎ', 'ழு'), ('Ġஅ', 'ழ'), ('Ġஅழ', 'கு'), ('Ġசெ', 'ம்'), ('த', 'ம்'), ('Ġமாவட்டத்தில்', 'தான்'), ('Ġமுத', 'ல்'), ('Ġதிரு', 'க்கு'), ('Ġ', '2'), ('Ġப', 'ணி'), ('Ġஅ', 'ணி'), ('Ġஇ', 'ங்கு'), ('Ġஎன்', 'ப'), ('Ġஉ', 'ல'), ('வர்', 'கள்'), ('வா', 'ச'), ('த', 'னி'), ('Ġஇ', 'ய'), ('ண்', 'ணா'), ('வ', 'ரும்'), ('ழி', 'ல்'), ('Ġஅமைந்துள்ள', 'து'), ('ருவி', ','), ('மா', 'ன'), ('மா', 'கும்'), ('Ġநி', 'று'), ('Ġநிறு', 'வ'), ('Ġநிறுவ', 'ன'), ('ப', 'டை'), ('Ġமை', 'யம்,'), ('Ġபோன்ற', 'வை'), ('னோ', 'ன்'), ('னோன்', 'மணி'), ('னோன்மணி ...
